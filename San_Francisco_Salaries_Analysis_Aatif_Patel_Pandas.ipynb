# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Lord\Downloads\Salaries.csv")
# Out:
# C:\Users\Lord\AppData\Local\Temp\ipykernel_19252\3449113861.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Lord\Downloads\Salaries.csv")

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# Drop Id , Notes , Agency And Status Columns

# %%
df.drop(['Id',"Status","Agency","Notes"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   EmployeeName      148654 non-null  object
#  1   JobTitle          148654 non-null  object
#  2   BasePay           148049 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   Benefits          112495 non-null  object
#  6   TotalPay          148654 non-null  float64
#  7   TotalPayBenefits  148654 non-null  float64
#  8   Year              148654 non-null  int64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 10.2+ MB

# %% [markdown]
# Get the Overall Statistics About the dataframe

# %%
df.describe(include="all")
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# Find the Occurrence of the Employee Name

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df["EmployeeName"].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# Find the name of the unique Job Title

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
unique_job_titles = df['JobTitle'].str.strip().unique()

# %%
pd.set_option('display.max_rows', len(unique_job_titles))

# %%
unique_job_titles_df = pd.DataFrame(unique_job_titles, columns=['UniqueJobTitles'])

# %%
print(unique_job_titles_df)
# Out:
#                                      UniqueJobTitles
# 0     GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                    CAPTAIN III (POLICE DEPARTMENT)
# 2               WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3       DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4                          ASSISTANT DEPUTY CHIEF II
# ...                                              ...
# 2154                    Sr Cnselor, Juv Hall (SFERS)
# 2155                  Forensic Toxicologist Supervis
# 2156                                      Conversion
# 2157                                       Cashier 3
# 2158                                    Not provided
#
# [2159 rows x 1 columns]

# %%
print(unique_job_titles)
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']

# %%
df["JobTitle"].nunique()
# Out:
# 2159

# %%
df["JobTitle"].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %%
df["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                                      7036
# Special Nurse                                         4389
# Registered Nurse                                      3736
# Public Svc Aide-Public Works                          2518
# Police Officer 3                                      2421
# Custodian                                             2418
# TRANSIT OPERATOR                                      2388
# Firefighter                                           2359
# Recreation Leader                                     1971
# Patient Care Assistant                                1945
# Deputy Sheriff                                        1933
# Police Officer                                        1476
# SPECIAL NURSE                                         1402
# Public Service Trainee                                1328
# REGISTERED NURSE                                      1219
# Police Officer 2                                      1141
# ...

# %% [markdown]
# Total Number of job title contain captain

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df["JobTitle"]
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df[df["JobTitle"].str.strip().str.contains("CAPTAIN",case=False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# dtype: int64

# %% [markdown]
# Display All the Employee names From Fire Department

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df[df["JobTitle"].str.strip().str.contains("FIRE DEPARTMENT",case=False)]["EmployeeName"]
# Out:
# 4                 PATRICK GARDNER
# 6                       ALSON LEE
# 8                  MICHAEL MORRIS
# 9              JOANNE HAYES-WHITE
# 10                  ARTHUR KENNEY
# 14                 DAVID FRANKLIN
# 18                     MARTY ROSS
# 23                  VICTOR WYRSCH
# 27                 RAYMOND GUZMAN
# 29                  MONICA FIELDS
# 34                      JOSE VELO
# 39                   BRENDAN WARD
# 40               MICHAEL THOMPSON
# 41                  THOMAS ABBOTT
# 42                THOMAS SIRAGUSA
# 46               BRYAN RUBENSTEIN
# 49                        KEN YEE
# 50                KIRK RICHARDSON
# 60                  KENNETH SMITH
# 63                  CHARLES CRANE
# 66                  ROBERT POSTEL
# 71             RICHARD BUSALACCHI
# 76                    KEVIN BURKE
# 79               EDUARDO GONZALEZ
# 81                 ROBERT WINSLOW
# 82                   LORRIE KALOS
# 86                 MICHAEL BRYANT
# ...

# %%
df["JobTitle_cleaned"] = df["JobTitle"].fillna("").str.strip()
print(df["JobTitle_cleaned"].unique())
filtered_df = df[df["JobTitle_cleaned"].str.contains("FIRE DEPARTMENT", case=False)]
employee_names = filtered_df['EmployeeName']
print(employee_names)
# Out:
# ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY'
#  'CAPTAIN III (POLICE DEPARTMENT)' 'WIRE ROPE CABLE MAINTENANCE MECHANIC'
#  ... 'Conversion' 'Cashier 3' 'Not provided']
# 4                 PATRICK GARDNER
# 6                       ALSON LEE
# 8                  MICHAEL MORRIS
# 9              JOANNE HAYES-WHITE
# 10                  ARTHUR KENNEY
# 14                 DAVID FRANKLIN
# 18                     MARTY ROSS
# 23                  VICTOR WYRSCH
# 27                 RAYMOND GUZMAN
# 29                  MONICA FIELDS
# 34                      JOSE VELO
# 39                   BRENDAN WARD
# 40               MICHAEL THOMPSON
# 41                  THOMAS ABBOTT
# 42                THOMAS SIRAGUSA
# 46               BRYAN RUBENSTEIN
# 49                        KEN YEE
# 50                KIRK RICHARDSON
# 60                  KENNETH SMITH
# 63                  CHARLES CRANE
# 66                  ROBERT POSTEL
# 71             RICHARD BUSALACCHI
# ...

# %% [markdown]
# Find Max Min and Average of BasePay

# %%
df.dropna(axis=0,how="any",inplace = True)

# %%
df["BasePay"].isnull().sum()
# Out:
# 0

# %%
df = df[df['BasePay'] != 'Not Provided']

# %%
df['BasePay'] = df['BasePay'].replace('Not Provided', np.nan)
# Out:
# C:\Users\Lord\AppData\Local\Temp\ipykernel_19252\438190402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BasePay'] = df['BasePay'].replace('Not Provided', np.nan)

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
# Out:
# C:\Users\Lord\AppData\Local\Temp\ipykernel_19252\3961763728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')

# %%
df["BasePay"].describe()
# Out:
# count    111886.000000
# mean      67207.558425
# std       43417.689463
# min        -166.010000
# 25%       33644.427500
# 50%       65547.035000
# 75%       95229.030000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# Find Job Title of Albert Pardini

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'JobTitle_cleaned'],
#       dtype='object')

# %%
df[df["EmployeeName"] == "Albert Pardini"]
# Out:
#          EmployeeName   JobTitle    BasePay OvertimePay  OtherPay  Benefits  \
# 36519  Albert Pardini  Captain 3  196265.04         0.0  11404.04  46326.21
#
#         TotalPay  TotalPayBenefits  Year JobTitle_cleaned
# 36519  207669.08         253995.29  2012        Captain 3

# %%
df[df["EmployeeName"] == "Albert Pardini"]["JobTitle"]
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %% [markdown]
# How Much Albert Pardini  Make including Benefits

# %%
df[df["EmployeeName"] == "Albert Pardini"]["TotalPayBenefits"]
# Out:
# 36519    253995.29
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# Display Name of the person Having Highest BasePay

# %%
df[df["BasePay"].max() == df["BasePay"]]
# Out:
#          EmployeeName         JobTitle    BasePay OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01         0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year JobTitle_cleaned
# 72925  86533.21  339282.07         425815.28  2013  Chief of Police

# %%
df[df["BasePay"].max() == df["BasePay"]]["EmployeeName"]
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %% [markdown]
# Find average basePay of all employee Per Year

# %%
df[df.groupby("Year").mean()["BasePay"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lord\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\Lord\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Lord\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# Find average basePay of all employee Per Jobtitle

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'JobTitle_cleaned'],
#       dtype='object')

# %%
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
df.groupby('JobTitle')['BasePay'].mean()
# Out:
# C:\Users\Lord\AppData\Local\Temp\ipykernel_19252\88076842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)        62290.780000
# ASR Senior Office Specialist       60551.580167
# ASR-Office Assistant               41253.471951
# Account Clerk                      42372.579396
# Accountant I                       61777.832500
# Accountant II                      66880.084425
# Accountant III                     78940.945000
# Accountant IV                      92423.801111
# Accountant Intern                  43713.649500
# Acupuncturist                      73630.166667
# Adm, SFGH Medical Center          265218.780000
# ...

# %% [markdown]
# Find Average BasePay of Employee Having Job Title Accountant

# %%
df[df["JobTitle"].str.contains("Accountant", case=False)]["BasePay"].dropna().mean()
# Out:
# 75336.18288798921

# %% [markdown]
# Top 5 most common Jobs

# %%
df["JobTitle"].value_counts().head()
# Out:
# JobTitle
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: count, dtype: int64
